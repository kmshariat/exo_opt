# %%
pip install lightkurve
# Out:
# Requirement already satisfied: lightkurve in /usr/local/lib/python3.10/dist-packages (2.5.0)
# Requirement already satisfied: astropy>=5.0 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (6.1.7)
# Requirement already satisfied: astroquery>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (0.4.7)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (4.12.3)
# Requirement already satisfied: bokeh>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (3.6.2)
# Requirement already satisfied: fbpca>=1.0 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (1.0)
# Requirement already satisfied: matplotlib>=3.1 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (3.8.0)
# Requirement already satisfied: memoization>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (0.4.0)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (1.26.4)
# Requirement already satisfied: oktopus>=0.1.2 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (0.1.2)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (2.2.2)
# Requirement already satisfied: patsy>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (1.0.1)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (2.32.3)
# Requirement already satisfied: s3fs>=2024.6.1 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (2024.12.0)
# Requirement already satisfied: scikit-learn>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (1.6.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (1.13.1)
# Requirement already satisfied: tqdm>=4.25.0 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (4.67.1)
# Requirement already satisfied: uncertainties>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (3.2.2)
# Requirement already satisfied: urllib3>=1.23 in /usr/local/lib/python3.10/dist-packages (from lightkurve) (2.2.3)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.10/dist-packages (from astropy>=5.0->lightkurve) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2024.10.28.0.34.7 in /usr/local/lib/python3.10/dist-packages (from astropy>=5.0->lightkurve) (0.2024.12.16.0.35.48)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy>=5.0->lightkurve) (6.0.2)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=5.0->lightkurve) (24.2)
# Requirement already satisfied: html5lib>=0.999 in /usr/local/lib/python3.10/dist-packages (from astroquery>=0.3.10->lightkurve) (1.1)
# Requirement already satisfied: keyring>=15.0 in /usr/lib/python3/dist-packages (from astroquery>=0.3.10->lightkurve) (23.5.0)
# Requirement already satisfied: pyvo>=1.1 in /usr/local/lib/python3.10/dist-packages (from astroquery>=0.3.10->lightkurve) (1.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.6.0->lightkurve) (2.6)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.3.2->lightkurve) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.3.2->lightkurve) (1.3.1)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.3.2->lightkurve) (11.0.0)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.3.2->lightkurve) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.3.2->lightkurve) (2024.9.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->lightkurve) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->lightkurve) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->lightkurve) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->lightkurve) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->lightkurve) (2.8.2)
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (from oktopus>=0.1.2->lightkurve) (1.7.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->lightkurve) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->lightkurve) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->lightkurve) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->lightkurve) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->lightkurve) (2024.12.14)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /usr/local/lib/python3.10/dist-packages (from s3fs>=2024.6.1->lightkurve) (2.16.1)
# Requirement already satisfied: fsspec==2024.12.0.* in /usr/local/lib/python3.10/dist-packages (from s3fs>=2024.6.1->lightkurve) (2024.12.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from s3fs>=2024.6.1->lightkurve) (3.11.10)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.0->lightkurve) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.0->lightkurve) (3.5.0)
# Requirement already satisfied: botocore<1.35.89,>=1.35.74 in /usr/local/lib/python3.10/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve) (1.35.88)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /usr/local/lib/python3.10/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve) (1.17.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve) (0.12.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (1.18.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=0.999->astroquery>=0.3.10->lightkurve) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=0.999->astroquery>=0.3.10->lightkurve) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh>=2.3.2->lightkurve) (3.0.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.89,>=1.35.74->aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve) (1.0.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (4.12.2)

# %%
pip install wotan
# Out:
# Requirement already satisfied: wotan in /usr/local/lib/python3.10/dist-packages (1.10)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from wotan) (1.26.4)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from wotan) (0.60.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from wotan) (1.13.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->wotan) (0.43.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import lightkurve as lk
from wotan import flatten
import math

# %%
id = 'TIC 284475976'

# %% [markdown]
# The `TransitOverview` function overviews all the light curves for a TIC id.

# %%
def TransitOverview(id):
    datasets = lk.search_lightcurve(id)
    num_datasets = len(datasets)

    if num_datasets == 0:
        print(f"No datasets found for TIC ID {id}.")
        return None

    # Grid
    cols = 5
    rows = math.ceil(num_datasets / cols)
    fig, axes = plt.subplots(rows, cols, figsize=(20, rows * 2))
    axes = axes.flatten()

    # progress bar
    for i in range(num_datasets):
        data_raw = datasets[i].download()
        time_raw = data_raw.time.value
        flux_raw = data_raw.flux.value

        axes[i].scatter(time_raw, flux_raw, color='#363636', marker='.')
        axes[i].set_xticks([])
        axes[i].set_yticks([])
        axes[i].set_title(f"Set # {i + 1}")

    # Hide unused axes
    for j in range(num_datasets, len(axes)):
        axes[j].axis('off')

    plt.tight_layout()
    plt.show()

    return fig, num_datasets

# %%
#TransitOverview(id)

# %%
data = lk.search_lightcurve(id)[6].download()
time_real = data.time.value
flux_real = data.flux.value.unmasked
flux_err_real = data.flux_err.value.unmasked

# %%
plt.figure(figsize = (10, 5))
plt.errorbar(time_real, flux_real, flux_err_real, fmt = '.', color = '#363636')
plt.title(f'Real Data of Transiting Exoplanet {id}')
plt.xlabel('Time')
plt.ylabel('Flux')
# Out:
# Text(0, 0.5, 'Flux')

# %% [markdown]
# Detrending

# %%
flatten_lc, trend_lc = flatten(
    time_real,                 # Array of time values
    flux_real,                 # Array of flux values
    method='biweight',
    window_length=0.75,    # The length of the filter window in units of ``time``
    edge_cutoff=0.5,      # length (in units of time) to be cut off each edge.
    break_tolerance=0.5,  # Split into segments at breaks longer than that
    return_trend=True,    # Return trend and flattened light curve
    cval=5.0              # Tuning parameter for the robust estimators
    )

# %%
plt.figure(figsize = (10, 5))
plt.scatter(time_real, flux_real, color='black', marker='.', label = 'Real Data')
plt.plot(time_real, trend_lc, color='red', linewidth=2, label='Trend')
plt.title(f'Trend of the Transit {id}')
plt.xlabel('Time')
plt.ylabel('FLux')
plt.show()

# %% [markdown]
# Periodogram

# %%
ls_pg = data.normalize().to_periodogram(maximum_period=8)   # lomb scargle
bls_pg = data.normalize().to_periodogram(method='bls')  # box least square

best_period = bls_pg.period_at_max_power.value
print(f"Period at maximum power is: {best_period}")

t0 = bls_pg.transit_time_at_max_power.value
print(f"Epoch of the transit is {t0}")

t_dur = bls_pg.duration_at_max_power.value
print(f"Transit Duration is {t_dur}")

fig, ax = plt.subplots(figsize=(10,6))
ax.plot(bls_pg.period, bls_pg.power, label='BLS', linewidth=0.5, color='#363636')
plt.xlabel('Period')
plt.title(f'Period at Max Power {best_period}')
plt.ylabel('Power')
plt.show()
# Out:
# Period at maximum power is: 2.145870344575141
# Epoch of the transit is 2746.1372446150467
# Transit Duration is 0.1

# %% [markdown]
# Phase Folding

# %%
phase_fold = data.normalize().fold(period=best_period)
phase_folded_time_real = phase_fold.time.value
phase_folded_flux_real = phase_fold.flux.value
plt.figure(figsize=(10,6))
plt.scatter(phase_folded_time_real, phase_folded_flux_real, color='#363636', marker='.', s = 0.75)
plt.title(f'Phase Folded Data of {id}')
plt.xlabel('Phase')
plt.ylabel('Flux')
plt.show()

# %% [markdown]
# Mandel-Agol Model Fitting

# %%
# !pip install batman-package
# Out:
# Requirement already satisfied: batman-package in /usr/local/lib/python3.10/dist-packages (2.4.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from batman-package) (1.26.4)

# %%
import batman

# %%
params = batman.TransitParams()
params.t0 = t0                       #time of inferior conjunction
params.per = best_period                      #orbital period
params.rp = 0.1                      #planet radius (in units of stellar radii)
params.a = 5.                       #semi-major axis (in units of stellar radii)
params.inc = 87.                     #orbital inclination (in degrees)
params.ecc = 0.                      #eccentricity
params.w = 90.                       #longitude of periastron (in degrees)
params.u = [0.1, 0.3]                #limb darkening coefficients [u1, u2]
params.limb_dark = "quadratic"       #limb darkening model

# %%
lc_start = time_real[0]
lc_stop = time_real[-1]
time_model = np.linspace(lc_start, lc_stop, len(data))

m = batman.TransitModel(params, time_model)    #initializes model
flux_model = m.light_curve(params)          #calculates light curve

# %%
plt.plot(time_model, flux_model, color='red', linewidth=2, label='Mandel-Agol Model')
plt.legend()
plt.show()

# %%
def phase_fold(t, f, p, t0, e=None):
    """
    Phase fold time and flux arrays in unit of days
    where phase=0=t0
    """
    fold = ((t - t0) % p) / p
    fold[fold > 0.5] -= 1  # Shift to [-0.5, 0.5]
    phase_sort = np.argsort(fold)
    phase_time = fold[phase_sort]
    phase_flux = f[phase_sort]
    if e is not None:
        phase_flux_err = e[phase_sort]
        return phase_time, phase_flux, phase_flux_err
    return phase_time*best_period, phase_flux

# %%
phase_folded_model = phase_fold(t= time_model, f= flux_model, p = best_period, t0=t0)
phase_folded_time_model = phase_folded_model[0]
phase_folded_flux_model = phase_folded_model[1]

# %%
t = np.linspace(-1, 1, len(phase_folded_time_model))

plt.figure(figsize=(10,5))
plt.xlabel("Time from central transit")
plt.ylabel("Relative flux")
plt.scatter(phase_folded_time_real, phase_folded_flux_real, color='#363636', marker='.', s = 1, label='Phase Folded Data')
plt.plot(phase_folded_time_model, phase_folded_flux_model, color='red', linewidth=3, label='Mandel-Agol Model')
plt.legend()

plt.show()

# %% [markdown]
# Nelder-Mead Optimization

# %%
# clean
d = data[['time','flux','flux_err']].remove_nans()

# %%
initial = [0.1, 5, 90, t0, best_period, 0.1, 0.3]
bounds  = [(0, 1),  #rp
           (1, 100), #a
           (80, 90), #i
           (time_real[0], time_real[-1]), #t0
           (0, 10), #p
           (0, 1), #u1
           (0, 1) #u2
           ]
# phase fold
raw_data = phase_fold(t=np.array(d.time.value.tolist()),
           f=np.array(d.flux.value.tolist()),
           p=best_period,
           t0=0,
           e=np.array(d.flux_err.value.tolist()),
           )

# %%
def log_likelihood(theta, data):
    """
    Assume Gaussian likelihood function
    theta : model parameters (rp, a, i, t0, p, u1, u2)
    data  : phase-folded time, flux, flux_err
    """
    # phase fold data
    phase_time, phase_flux, phase_flux_err = data
    # unpack free parameters
    rp, a, i, t0, p, u1, u2 = theta
    params = batman.TransitParams()
    params.ecc = 0.                      #eccentricity
    params.w = 90.                       #longitude of periastron (in degrees)
    params.limb_dark = "quadratic"       #limb darkening model
    params.t0 = t0                       #time of inferior conjunction
    params.per = p                      #orbital period
    params.rp = rp                      #planet radius (in units of stellar radii)
    params.a = a                       #semi-major axis (in units of stellar radii)
    params.inc = i                     #orbital inclination (in degrees)
    params.u = [u1, u2]                #limb darkening coefficients [u1, u2]
    # build model
    t_model = np.linspace(lc_start, lc_stop, len(phase_time))
    m = batman.TransitModel(params, t_model)    #initializes model
    f_model = m.light_curve(params)
    # # phase fold model
    # phase_model, phase_flux_model = phase_fold(t_model, f_model, p, t0)
    # sigma = np.sqrt(phase_flux_err**2+err**2)
    # return -0.5 * np.sum(np.log(2*np.pi*sigma**2)) * np.sum((phase_flux - phase_flux_model)**2/sigma**2)
    phase_model, phase_flux_model = phase_fold(t_model, f_model, p, t0)
    return -0.5 * np.sum((phase_flux - phase_flux_model)**2/phase_flux_err**2)


def log_prior(theta):
    """
    Assume uniform prior for all model parameters (rp, a, i, t0, p, u1, u2)
    """
    rp, a, i, t0, p, u1, u2 = theta
    if (bounds[0][0] < rp < bounds[0][1])\
        & (bounds[1][0] < a < bounds[1][1])\
        & (bounds[2][0] < i <= bounds[2][1])\
        & (bounds[3][0] < t0 < bounds[3][1])\
        & (bounds[4][0] < p < bounds[4][1])\
        & (bounds[5][0] < u1 < bounds[5][1])\
        & (bounds[6][0] < u2 < bounds[6][1])\
        & (a*np.cos(np.deg2rad(i)) < 1):
      return 0.0
    return -np.inf


def log_probability(theta, data):
    """
    Mulitply prior and likelihood
    """
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(theta, data)
nlp = lambda *args: -log_probability(*args)

# %%
# check each component
log_likelihood(initial, raw_data), log_prior(initial), log_probability(initial, raw_data)
# Out:
# (-1843778329.2049708, 0.0, -1843778329.2049708)

# %%
from scipy.optimize import minimize

# %%
soln = minimize(nlp, initial, method='nelder-mead', args=(raw_data,))

# %%
param_names = ['rp', 'a', 'i', 't0', 'p', 'u1', 'u2']
if soln.success:
    print("Optimized parameters:")
    for x,param in zip(soln.x, param_names):
        print(f"{param}: {x:.2f}")
else:
    print("Optimization unsuccessful!")
# Out:
# Optimized parameters:
# rp: 0.00
# a: 6.24
# i: 88.62
# t0: 2752.54
# p: 2.05
# u1: 0.15
# u2: 0.35

# %% [markdown]
# ### MCMC Optimization

# %%
pip install emcee
# Out:
# Collecting emcee
#   Downloading emcee-3.1.6-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from emcee) (1.26.4)
# Downloading emcee-3.1.6-py2.py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: emcee
# Successfully installed emcee-3.1.6

# %%
pip install corner
# Out:
# Collecting corner
#   Downloading corner-2.2.3-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: matplotlib>=2.1 in /usr/local/lib/python3.10/dist-packages (from corner) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1->corner) (1.17.0)
# Downloading corner-2.2.3-py3-none-any.whl (15 kB)
# Installing collected packages: corner
# Successfully installed corner-2.2.3

# %%
from multiprocessing import Pool
import corner
import emcee

# %%
nparams = len(soln.x) #free parameters
nwalkers = nparams*10
pos = soln.x + 1e-4 * np.random.randn(nwalkers, nparams)

# %%
np.random.randn(nwalkers, nparams).shape
# Out:
# (70, 7)

# %%
# initialize walkers randomly offset around the optimized solution
initial_pos = np.random.randn(nwalkers, nparams) + soln.x + 1e-4
initial_pos[0]
# Out:
# array([-4.60168954e-01,  5.62910277e+00,  8.88685072e+01,  2.75250082e+03,
#         3.56641851e+00,  6.36331892e-01, -1.22074303e+00])

# %%
# run mcmc for 1000 steps in parallel using pool
with Pool() as pool:
    sampler = emcee.EnsembleSampler(nwalkers, nparams, log_probability, args=(raw_data,), pool=pool)
    sampler.run_mcmc(initial_pos, 1000, progress=True);
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# 100%|██████████| 1000/1000 [01:09<00:00, 14.42it/s]

# %%
fig, axs = plt.subplots(nparams, 2, figsize=(10, nparams), sharex=True)
ax = axs.flatten()

for i, history in enumerate(sampler.chain[:,:,:].T):
    ax[i].plot(history, drawstyle='steps', color='k', alpha=0.2)
    ax[i].set_ylabel(param_names[i])

# %% [markdown]
# Corner Plot

# %%
import corner

fig = corner.corner(sampler.get_chain(),
                    labels=param_names,
                    show_titles=True,
                    title_quantiles=[0.16, 0.5, 0.84])
# Out:
# /usr/local/lib/python3.10/dist-packages/arviz/data/base.py:272: UserWarning: More chains (1000) than draws (70). Passed array should have shape (chains, draws, *shape)
#   warnings.warn(
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
